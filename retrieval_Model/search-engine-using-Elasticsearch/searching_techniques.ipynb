# %%
from elasticsearch import Elasticsearch
from elasticsearch_dsl import Search

client = Elasticsearch('localhost:9200')

# %%
s = Search(using=client, index="dataset") \
    .filter("term", category="search") \
    .query("match", title="python")   \
    .exclude("match", description="beta")

# %%
s = Search(using=client, index="docomo").query("match", text="変更 当該 または")

# %%
response = s.execute()
response
# Out:
# <Response: [<Hit(docomo/99): {'page': 99, 'title': ' ごろ  アイテム  ジョブ 知り たい  マーケット', 'text':...}>, <Hit(docomo/1087): {'page': 1087, 'title': 'スマホワーク 新規 登録 キャンペーン  ジョブ スマホワーク', '...}>, <Hit(docomo/1089): {'page': 1089, 'title': 'アプリデビュー  もれ なく  もらえる キャンペーン  ジョブ スマ...}>, <Hit(docomo/1088): {'page': 1088, 'title': 'LINE 登録 キャンペーン  ジョブ スマホワーク', 'text'...}>, <Hit(docomo/1185): {'page': 1185, 'title': '求人 情報 詳細  知り たい TAG  ジョブ 求人 情報', 't...}>, <Hit(docomo/1202): {'page': 1202, 'title': 'メール マガジン   TAG  ジョブ 求人 情報', 'text':...}>, <Hit(docomo/1187): {'page': 1187, 'title': '希望 条件  あっ  アルバイト  紹介   ほしい TAG  ジョブ...}>, <Hit(docomo/1090): {'page': 1090, 'title': '友達 紹介 キャンペーン  ジョブ スマホワーク', 'text': ...}>, <Hit(docomo/1207): {'page': 1207, 'title': 'メール マガジン  配信  停止     関わら  メール マガジン ...}>, <Hit(docomo/1228): {'page': 1228, 'title': ' ジョブ TAG  ジョブ 求人 情報', 'text': ' ジョブ...}>]>

# %%
for hit in response:
    print(hit.meta.score, hit.text)
# Out:
# 10.01546  マーケット  よく ある  質問 各種 設定  回答 ありがとう ござい まし  いいえ はい この 情報  役に立ち まし   また 作成    アイテム  有効 期限   ジョブ   適用   ます ので 何卒  注意 ください  ジョブ  一覧   好き  アイテム   自身  選択   いただき その アイテム  作成  できる です  ごろ  アイテム  ジョブ 知り たい よく ある  質問 なお  ジョブ  効果 にて 作成    アイテム  まし     ごろ   プレイ   利用  なり ます
# 9.637319 ポイント 進呈 時点   ポイント クラブ 会員  ある ④ キャンペーン 期間   ジョブ スマホワーク  仕事  完了    回数   件数 件 承認 済  数え ます ③ クラウドワークス  取り扱う 仕事  対象  なり ます ポイント 進呈  ジョブ スマホワーク   利用 登録  継続    いる お客 さま  本 キャンペーン 適用 条件  満たす  費用 インターネット 通信  お客 さま   負担  なり ます キャンペーン 期間   ジョブ スマホワーク  初めて 利用 登録    ① 適用 条件 キャンペーン 期間   適用 条件   満たし  お客 さま   ポイント 期間 用途 限定        抽選  プレゼント いたし ます エントリー  不要 です キャンペーン 概要 期間  NTT DOCOMO 登録    アカウント  作成  必要 です キャンペーン 期間  ひとり さま 適用  なり ます 同 一人物 による 複数  応募  発覚   結果  かかわら  ポイント 進呈 対象 または ポイント 進呈 取消     いただく  あり ます ので  注意 ください ② 第三者   ポイント 進呈 権  譲渡  でき ませ  プレゼント ポイント 詳細 および 進呈 時期  ポイント 期間 用途 限定   ドコモ  スマート フォン  購入  マーケット ローソン  街   店   利用 幅広い 用途   利用 いただけ ます  通常   ポイント  異なり 利用 用途  限定   進呈  固有  有効 期間  設定     ます ポイント 進呈 時期 新規 登録 仕事  完了 いただい  翌月 下旬 頃 ポイント 有効 期限 ポイント 進呈  予定 ポイント  有効 期限  進呈 時点  変更  なる  あり ます 詳しく  ポイント 進呈   確認 ください 注意 事項 当選 ポイント 数  発表  ポイント  進呈  もっ  代え させ  いただき ます 本 規約  記載  注意 事項  必ず  確認 ください 本 規約 違反  あっ  本 キャンペーン   参加 および 進呈  無効  なり ます 受付 状況  抽選 結果 に関する  問合せ   お答え いたし かね ます ので 予め  了承 ください 本 キャンペーン  内容  予告 なく 変更  なる  ござい ます また 本 規約  当社  判断 により 随時 改定  ござい ます この 当社  本 キャンペーン サイト  掲載 により 本 キャンペーン 内容  変更 または 本 規約  改定  内容  随時 告知   ます 当該 告知 当該 変更 または 改定 内容   お客 さま  当社   間  適用   いたし ます ので 予め  了承 ください 当社  本 キャンペーン  適切  運営  妨げる 事象  生じ   類する 状況  生じ  または 本 キャンペーン  継続  難い 事由  生じ  本 キャンペーン  中止 または 延期  できる  いたし ます 当社  お客 さま  本 キャンペーン  参加    起因 損害 不利益 一切  責任  負わ ない  いたし ます 当社  ネットワーク 環境  不具合  システム メンテナンス により 適用 条件  満たさ  なかっ   あっ   当社  一切  責任  負い かね ます ので 予め  了承 ください お客 さま  情報  取り扱い 当社  本 キャンペーン  運営  関連   取得   お客 さま  個人 情報  適用 条件  満たし  いる  確認 お客 さま    連絡 抽選 および プレゼント  発送 本 キャンペーン  運営 に関する 目的   利用  商品 開発 サービス 向上 および キャンペーン 実施  検討  目的  当該 目的  必要  範囲  限り 利用  あり ます なお 当社  お客 さま  個人 情報  流出 漏えい  防止 個人 情報  安全 管理   必要 かつ 適切  処置  講じる   法令  基づく 正当  理由  ある  除き お客 さま  同意  目的   利用 および 第三者 業務 委託  除く   提供  いたし ませ  ポイント  進呈 前   ジョブ スマホワーク  退会   本 キャンペーン  条件  満たさ なく なっ   ポイント 進呈 対象 または ポイント 進呈 取消  なる  あり ます 株式会社 NTT ドコモ 当社  いい ます  実施  ジョブスマホワーク 新規 登録 キャンペーン 本 キャンペーン  いい ます  この 規約 本 規約  いい ます に従って 実施   ます 本 キャンペーン  適用 にあたって   内容   確認 ください 否認     仕事  対象  なり ます クラウドワークス   仕事  対象  なり ます  ジョブ スマホワーク  登録    アカウント  作成  必要 です  ポイント 期間 用途 限定
# 9.599015  ジョブ スマホワークアプリ   ジョブアプリ   異なり ます ので  注意 ください 適用 条件 ① キャンペーン ページ エントリー いただい  ② ポイント 進呈  ジョブ スマホワーク   利用 登録  継続    いる ③ ポイント 進呈 時点   ポイント クラブ 会員  ある ④ キャンペーン 期間  初めて  ジョブ スマホワークアプリ  プッシュ 通知  ON   判定  時点   通知 ON  なっ  いる 期間  キャンペーン  エントリー  サービス   利
この 当社  本 キャンペーン サイト  掲載 により 本 キャンペーン 内容  変更 または 本 規約  改定  内容  随時 告知   ます 当該 告知 当該 変更 または 改定 内容   お客 さま  当社   間  適用   いたし ます ので 予め  了承 ください 適用 条件 ①  ジョブ 公式 LINE アカウント  友だち 追加 いただい   適用 条件  満たし   ポイント 進呈 時期  下旬 頃 ポイント 有効 期限  末日  なり ます ② 期間  対象  アンケート   完了 いただい   ジョブ スマホワーク  無料 利用 登録  必要 ③ ポイント 進呈 時点   ポイント クラブ 会員  ある 過去   ジョブ 公式 LINE アカウント  友だち 追加 いただき  ポイント 期間 用途 限定  進呈     対象  なり ます プレゼント ポイント 詳細 および 進呈 時期 キャンペーン 期間  ひとり さま 適用  なり ます 同 一人物 による 複数  応募  発覚   ポイント 進呈 対象 または ポイント 進呈 取消     いただく  あり ます ので  注意 ください 本 規約  記載  注意 事項  必ず  確認 ください 代 女性 まとめ  応募  希望  場所  働ける 可能 性  UP かも バイト  派遣  正社員  ぴったり  求人  見つけ  まとめ  応募 しよ  スキマ 時間  できる  仕事  探し     です  色んな 時間  求人  ある ので すぐ 見つかり まし  シニア 向け  想像  あり ビックリ スマ   得意   ない 私  まとめ  応募 できる ので 助かり ます 代 女性 結構   絞れ ない 性格   です  毎日 オススメ  求人  LINE  届く ので 迷わ  決め  まし  笑 個人  感想 です 使用    いる 写真  イメージ です 本 キャンペーン ページ  QR コード 代 男性  読み取る または まとめ  応募 できる 気  なる 最新   仕事 情報  届く  トク  キャンペーン 情報  届く 複数  求人  一  人気 求人 まとめ  探せる 有名 サイト 社  人気 求人  たくさん 掲載 サイト  行か なく    ジョブ  網羅 できる ので 便利 スマホ  パソコン  サクッ  求人  検索 でき ます 求人 詳細 ページ  見る  翌日 オススメ 求人  届く AI による 機械 学習  最適  求人  紹介 毎日 最大 件  オススメ 求人  届き LINE 直接 応募  でき ます  有名 サイト  友だち 追加 ボタン LINE  トーク  本 キャンペーン に関する メッセージ  届く メッセージ  株式会社 NTT ドコモ 当社  いい ます  実施 LINE 友だち 登録 キャンペーン 本 キャンペーン  いい ます  この 規約 本 規約  いい ます に従って 実施   ます 本 キャンペーン  適用 にあたって   内容   確認 ください  押す キャンペーン 規約 キャンペーン 規約  こちら ミドル 世代   安心   応募 できる   ドコモ  基準  満たし  求人  アンケート  回答 ボタン  押す 事前   アカウント 登録  必須  なり ます アンケート  回答  仕事 完了 画面  出 エントリー 完了 スマホワークサイト  遷移 回線   契約 状況 によって エントリー でき ない  あり ます 詳しく  規約   確認 ください 女性  応募 率  割 働き やすい 求人  応募  たくさん さまざま  世代  求人 応募 ワケ  有名 サイト  多種 多様   仕事  掲載   いる
# 8.136666  ジョブ  提携 パートナー サイト 様  情報  統合   掲載   いる サイト  各  仕事 情報  詳細  お手数 です  一度  応募 いただき 企業 様  連絡  あっ   直接  問い合わせ ください
# 8.083124  ジョブ 定期  最新  求人 情報  キャンペーン   得  情報  メール  お送り サービス です
利用 用途  限定   進呈  固有  有効 期間  設定     ます  適用 条件  満たし   ポイント 進呈 時期  下旬 頃 ポイント 有効 期限  末日  なり ます  確認 ください ポイント  有効 期限  進呈 時点  変更  なる  あり ます 詳しく  ポイント 進呈  ポイント 進呈  予定 ポイント 有効 期限 紹介     友達   ジョブスマホワーク  利用 登録   翌月 下旬 頃 ポイント 進呈 時期  友達  ひとり 紹介 いただく   ポイント 期間 用途 限定    通り 進呈  ます ポイント 詳細 および 進呈 時期 本 規約  記載  注意 事項  必ず  確認 ください 複数  紹介 URL エントリー   最初  紹介 URL  エントリー 対象  なり ます 条件  満たし  お客 さま   ポイント   プレゼント いたし ます 株式会社 NTT ドコモ 当社  いい ます  実施 友達 紹介 キャンペーン 本 キャンペーン  いい ます  この 規約 本 規約  いい ます に従って 実施   ます 本 キャンペーン  適用 にあたって   内容   確認 ください キャンペーン  参加   エントリー  必要 です 確認 友達 紹介    ジョブスマホワーク   利用 登録  必要 です
# 7.4605975   考え られ ます ので  確かめ ください br 複数  アカウント   利用    おり メール マガジン 配信 解除     ない br 毎日 くじ  実施    いる br  求人 掲載 企業  メール マガジン  受信   いる br      ジョブ トップページ  メール サービス 登録 解除 チェック  外し  ください br  配信    メール マガジン  記載  箇所 メール マガジン 配信 停止  手続き  お願い いたし ます br br 解決   ない ジョブ サポート デスク 受信    メール メールアドレス 件名 時間   連絡 ください
# 7.457341  ジョブ  様々  求人 情報 サイト   仕事 情報  掲載   サイト です br  仕事 情報  毎日 更新    おり お客様  ワーク スタイル  あっ  求人 情報  まとめ  検索 まとめ  応募  でき ます br また アカウント  連携  あらかじめ プロフィール 登録 いただい  お客様  名前  住所  情報  利用   入力  省略   応募  でき ます

# %%
import json

# %%
search_param = {
    "query": {
        "match": {
            "text": "DVD",
#             "fuzziness": "AUTO",
#             "fuzzy_transpositions": True,
#             "operator":  "or",
#             "minimum_should_match": 1,
#             "analyzer": "my_kuromoji_analyzer"
        }
    }
}

# %%
# give high importance to specific fileds, here 4 times than text
search_param = {
  "query": {
    "multi_match": {
      "query": "DVD",
      "fields": ["title^4", "text"]
    }
  }
}

# %%
## SELECT * FROM table in SQL.
{ "match_all": {} }
{ "match": { "description": "Fourier analysis signals processing" }}
{ "match": { "date": "2014-09-01" }}
{ "match": { "visible": true }}

## all documents with the tag “math”. 
## The second query finds all documents with the tags “math” or “statistics”.
{ "term": { "tag": "math" }}
{ "terms": { "tag": ["math", "statistics"] }}

## run across multiple fields instead of just one.
{
  "multi_match": {
    "query": "probability theory",
    "fields": ["title", "body"]
  }
}

{
    "bool": {
        "must":     { "term": { "tag":    "math" }},
        "must_not": { "term": { "tag":    "probability"  }},
        "should": [
                    { "term": { "favorite": true   }},
                    { "term": { "unread":  true   }}
        ]
    }
}

{
   "filtered": {
     "query": { "match": { "body": "Probability Theory" }},
     "filter": { 
        "bool": {
          "must": {
            "range":  { "upvotes" : { "gt" : 20 } } 
           },
          "must_not": { "term":  { "tag": "frequentist" } }
        }
     }
  }
}

# %%
res= client.search(index='dataset', body=search_param)
for hit in res['hits']['hits']:
    print(hit['_source']['text'])
    print(hit['_score'])
    print('**********************')

# %%
res= es.search(index='megacorp',body={
        'query':{
            'bool':{
                'must':[{
                        'match':{
                            'first_name':'nitin'
                        }
                    }]
            }
        }
    })

# %%
res= es.search(index='megacorp',body={
        'query':{
            'bool':{
                'must':{
                    'match':{
                        'first_name':'nitin'
                    }
                },
                "filter":{
                    "range":{
                        "age":{
                            "gt":25
                        }
                    }
                }
            }
        }
    })
print res['hits']['hits']

# %%
res= client.search(index='dataset', body={
        'query':{
            'match':{
                "text":"検索 時間 再度"
            }
        }
    })
for hit in res['hits']['hits']:
    print(hit['_source']['text'])
    print(hit['_score'])
    print('**********************')
# Out:
#  マガジン 資格 スキル アップ  ショッピング 雑誌 本 初回 日間 無料  ためし 各種 設定  前  ただいま 検索 結果  取得 でき ませ  時間  改めて 再度 検索   ください  指定  検索 条件  該当 商品  あり ませ  でし  あなた  おすすめ ビジネス ランキング  検索 結果 検索 キーワード  入力   ください もしかして 検索 ビジネス 使え  使う あなた  合っ  コンテンツ  表示   ます 閉じる
# 16.442574
# **********************
# 初回 日間 無料  ためし  ミュージック 音楽 洋楽  POP  ヒッツ  POP 前  各種 設定  ただいま 検索 結果  取得 でき ませ  時間  改めて 再度 検索   ください  指定  検索 条件  該当 商品  あり ませ  でし  アニメ 使え  使う あなた  合っ  コンテンツ  表示   ます 芸能 アイドル ランキング  検索 結果 閉じる 検索 キーワード  入力   ください もしかして 芸能 アイドル 検索 あなた  おすすめ  ショッピング テレビ
# 16.442574
# **********************
# CD DVD 音楽  ショッピング 洋楽  POP  ミュージック  POP  ヒッツ アニメ 初回 日間 無料  ためし 各種 設定  前  ただいま 検索 結果  取得 でき ませ  時間  改めて 再度 検索   ください  指定  検索 条件  該当 商品  あり ませ  でし  ヒップ ホップ   レゲエ 使え  使う あなた  合っ  コンテンツ  表示   ます あなた  おすすめ 音楽 ランキング  検索 結果 閉じる 検索 キーワード  入力   ください もしかして 検索 雑誌 本
# 16.290785
# **********************
# スポーツ ウェア 用品 雑誌 本 趣味 アウトドア スポーツ  マガジン 初回 日間 無料  ためし  ショッピング  ブック スポーツ  ゲーム ただいま 検索 結果  取得 でき ませ  時間  改めて 再度 検索   ください 動画 ゲーム 各種 設定  前   指定  検索 条件  該当 商品  あり ませ  でし   アニメ ストア あなた  おすすめ スポーツ ランキング  検索 結果 閉じる 検索 キーワード  入力   ください もしかして 検索 使え  使う あなた  合っ  コンテンツ  表示   ます
# 16.290785
# **********************
# 初回 日間 無料  ためし dTV ドラマ 韓 流 華 流 洋画 恋愛 青春 映画 各種 設定  前  ただいま 検索 結果  取得 でき ませ  時間  改めて 再度 検索   ください  指定  検索 条件  該当 商品  あり ませ  でし  SF ファンタジー 邦画 恋愛 ランキング  検索 結果 閉じる 検索 キーワード  入力   ください 検索 恋愛 もしかして あなた  おすすめ 海外 ドラマ 使え  使う あなた  合っ  コンテンツ  表示   ます
# 16.290785
# **********************
#  マガジン 雑誌 本 初回 日間 無料  ためし  トラベル 東北 ホテル 旅館 首都 圏 北関東 各種 設定  前  ただいま 検索 結果  取得 でき ませ  時間  改めて 再度 検索   ください 九州  指定  検索 条件  該当 商品  あり ませ  でし  あなた  おすすめ  でかけ ランキング 閉じる 検索 キーワード  入力   ください 検索  でかけ もしかして 使え  使う あなた  合っ  コンテンツ  表示   ます  検索 結果 近畿
# 16.142706
# **********************
# アニメ 初回 日間 無料  ためし ドラマ dTV  ショッピング 韓 流 華 流 CD DVD DVD 映画 キッズ 洋画 邦画 恋愛 青春  指定  検索 条件  該当 商品  あり ませ  でし  ただいま 検索 結果  取得 でき ませ  時間  改めて 再度 検索   ください 前  各種 設定  SF ファンタジー 使え  使う あなた  合っ  コンテンツ  表示   ます 映画 ドラマ あなた  おすすめ  しかして 検索 キーワード  入力   ください 閉じる 映画 ドラマ ランキング 検索  検索 結果
# 16.142706
# **********************
# 教育  キッズ 初回 日間 無料  ためし アニメ  POP  ヒッツ マタニティ ベビー キッズ 音楽 dTV キッズ  ショッピング 育児 おむつ ただいま 検索 結果  取得 でき ませ  時間  改めて 再度 検索   ください 各種 設定  前   指定  検索 条件  該当 商品  あり ませ  でし  使え  使う あなた  合っ  コンテンツ  表示   ます あなた  おすすめ キッズランキング  検索 結果 検索 キーワード  入力   ください もしかして 検索 閉じる 水 ソフトドリンク 季節  食品 食品
# 16.142706
# **********************
# 初回 日間 無料  ためし 恋愛  アニメ ストア 雑誌 本  ブック SF ファンタジー コメディ スポーツ アクション バトル 動画 ただいま 検索 結果  取得 でき ませ  時間  改めて 再度 検索   ください ほのぼの 各種 設定  前   指定  検索 条件  該当 商品  あり ませ  でし  ホラー サスペンス 推理 使え  使う あなた  合っ  コンテンツ  表示   ます 漫画 アニメ ランキング  検索 結果 閉じる 検索 キーワード  入力   ください もしかして 検索 漫画 アニメ あなた  おすすめ
# 16.142706
# **********************
#  ショッピング 資格 スキル アップ  ブック 雑誌 本 自己 啓発 音楽 各種 設定  前  ただいま 検索 結果  取得 でき ませ  時間  改めて 再度 検索   ください  指定  検索 条件  該当 商品  あり ませ  でし  あなた  おすすめ 習う ランキング  検索 結果 閉じる 検索 キーワード  入力   ください もしかして 検索 習う 使え  使う あなた  合っ  コンテンツ  表示   ます CD DVD
# 16.11793
# **********************

# %%
response = client.search(index="dataset", body=search_param)

# %%
print(response['hits']['hits'])

# %%
response

# %%
## Phrase Search
## match exact sequence of words of phrases.
res= es.search(index='megacorp',doc_type='employee',body={
        'query':{
            'match_phrase':{
                "about":"play cricket"
            }
        }
    })

# %%
res= client.search(index='docomo', body={
    "query": {
        "multi_match" : {
            "query" : "NTTs ドコモ 当社",
            "fields": ["text","title"],
            "fuzziness": 2
        }
    },
    "size": 10
})

# %%
res= client.search(index='docomo', body={
  "query": {
    "match": {
        "text" : "NTTs ドコモ 当社"
      }
    }
  })

# %%
# http://man.hubwiz.com/docset/ElasticSearch.docset/Contents/Resources/Documents/www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-regexp-query.html
# https://www.elastic.co/guide/en/elasticsearch/reference/current/regexp-syntax.html
res= client.search(index='docomo', body={
  "query": {
    "regexp": {
        "text" : "NTT"
      }
    }
  })

# %%
for hit in res['hits']['hits']:
    print(hit['_score'], " page:", hit['_id'])
    print(hit['_source']['text'])
    print('**********************')

# %%
print(res['hits']['hits'])
# Out:
# []
