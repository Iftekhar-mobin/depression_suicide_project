# %%
import re
import pandas as pd

# %%
result = ['activity Start service', 'service Start broadcast', 'service 示さ いる', 'App cloud service', 'com samsung syncservice', 'service 指定 アプリ', 'services soti net', 'サーバ https mobicontrolservice', 'ます https mobicontrolservice', 'Push Notification service', 'service 通知 Notice', 'ください https mobicontrolservice', 'service VPP ライセンス', 'Apple VPP service', 'service に関する Apple', 'content management service', 'service MobiControl ハイライト', 'service 追加 SOTI', 'Enrollment role service', 'service URL チャレンジ', 'service URL 静的', 'sent to service', 'service during time', 'The system service', 'service agent in']

# %%
pattern = 'service'

front_seq_word = []
rear_seq_word = []
for items in result:    
    for match in re.finditer(pattern, items):
        match = items[match.start(): match.end()]
        front_seq_word.append()
        rear_seq_word.append(items[match.start(): match.end()])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-9e5fb8a7e370> in <module>
#       6     for match in re.finditer(pattern, items):
#       7         match = items[match.start(): match.end()]
# ----> 8         front_seq_word.append()
#       9         rear_seq_word.append(items[match.start(): match.end()])
#
# TypeError: append() takes exactly one argument (0 given)

# %%
target_source = [['activity Start','service'], 
                 ['service', 'Start broadcast'], 
                 ['service', '示さ いる'], 
                 ['App cloud','service'], 
                ['com samsung sync','service'], 
                 ['service', '指定 アプリ'], 
                 ['service','soti net'], 
                ['サーバ https mobicontrol','service'],
                 ['ます https mobicontrol', 'service'], 
                 ['Push Notification','service'], 
                 ['service','通知 Notice'], 
                 ['ください https mobicontrol','service'], 
                 ['service','VPP ライセンス'], 
                 ['Apple VPP','service'], 
                ['service','に関する Apple'], 
                 ['content management','service'], 
                 ['service','MobiControl ハイライト'], 
                 ['service','追加 SOTI'], 
                 ['Enrollment role','service'], 
                ['service', 'URL チャレンジ'], 
                 ['service', 'URL 静的'], 
                 ['sent to','service'], 
                  ['service','during time'], 
                 ['The system','service'], 
                  ['service','agent in']]

# %%
df = pd.DataFrame(target_source, columns = ['source', 'target'])

# %%
df.head()
# Out:
#              source           target
# 0    activity Start          service
# 1           service  Start broadcast
# 2           service            示さ いる
# 3         App cloud          service
# 4  com samsung sync          service

# %%
import networkx as nx
import matplotlib.pyplot as plt
import matplotlib
import os
# %matplotlib inline

# %%
# font setting
# fp = matplotlib.font_manager.FontProperties(fname=os.path.expanduser('/usr/share/fonts/opentype/noto/NotoSansCJK-Regular.ttc'))
# plt.rcParams['font.family'] = fp.get_name()

kg_df = pd.DataFrame({'source': df['source'], 'target': df['target'], 'edge': df['target']})
G=nx.from_pandas_edgelist(kg_df, 'source', 'target', edge_attr=True, create_using=nx.MultiDiGraph())
plt.figure(figsize=(12,12))
pos = nx.spring_layout(G, k = 0.7)
nx.draw(G, with_labels=True, node_color='skyblue', edge_cmap=plt.cm.Blues, pos=pos, node_size=1500, fontsize=14, font_family="Noto Sans CJK JP")
#nx.draw_networkx_labels(G, pos, fontsize=14, 

plt.show()
