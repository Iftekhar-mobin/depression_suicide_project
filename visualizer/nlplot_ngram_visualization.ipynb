# %%
import gensim

# %%
gensim.

# %%
import sys
import ast
from os import path
import pandas as pd
sys.path.insert(0, '/home/iftekhar/AI-system/visualizer/nlplot/')
from nlplot import CorpusVisualizer
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_5465/3805963807.py in <module>
#       4 import pandas as pd
#       5 sys.path.insert(0, '/home/iftekhar/AI-system/visualizer/nlplot/')
# ----> 6 from nlplot import CorpusVisualizer
#
# ~/work/AI-system/visualizer/nlplot/__init__.py in <module>
# ----> 1 from nlplot.nlplot import *
#       2
#       3 def main():
#       4     pass
#
# ~/work/AI-system/visualizer/nlplot/nlplot.py in <module>
#      25 from networkx.algorithms import community
#      26 import gensim
# ---> 27 import pyLDAvis.gensim
#      28 if is_notebook():
#      29     pyLDAvis.enable_notebook()
#
# ModuleNotFoundError: No module named 'pyLDAvis.gensim'

# %%
# from nlplot import NLPlot
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-2077d88929da> in <module>
# ----> 1 from nlplot import NLPlot
#
# ImportError: cannot import name 'NLPlot'

# %%
file = open(path.join('/home/ifte/resource/docomo_dic/data/', "tokenized_dict.json"), "r")
contents = file.read()
features_dict = ast.literal_eval(contents)
file.close()

# %%
ids = [x for x in range(1)]
data = [x for sub in [features_dict[str(i)] for i in ids] for x in sub]

# %%
# df = pd.DataFrame(enumerate(features_dict['0']), columns=['page_id', 'text'])
df = pd.DataFrame(enumerate(data), columns=['page_id', 'text'])

# %%
df.head(25)

# %%
df = df[df['text']!='']

# %%
df
# Out:
#     page_id                                               text
# 0         0  メニュー top 人気 メニュー  メニュー dマーケット サービス 一覧 dアカウント 関...
# 2         2                 ポイント  つかう 貯まる  ポイント  ポイント 円  いただける
# 3         3  最大 半額  試せる  得  商品 話題  日用品 食品  なんと 半額  試せる もちろん...
# 5         5                                       クーポン 汚涜  セール
# 7         7                      クーポン 情報  更新 無料  もらえる 新 商品  人気
# 9         9                                         話題  商品  抽選
# 11       11  先着 方式  無料   試し いただける 口コミ  話題 口コミ  人気  商品   紹介 ...
# 13       13                                               エンタメ
# 15       15                                               スポーツ
# 17       17                            役立つ 情報  わかる トレンド 情報 まとめ
# 18       18  新着  買い物 エンタメ スポーツ テクノロジー  役立つ 無料  試せる 話題  映画  ...

# %%
# df = df.reset_index()
# df = df.drop(8)

# %%
# target_col as a list type or a string separated by a space.
npt = CorpusVisualizer(df, target_col='text')

# Stopword calculations can be performed.
stopwords = npt.get_stopword(top_n=30, min_freq=0)

# %%
# 1. N-gram bar chart
npt.bar_ngram(title='uni-gram', ngram=1, top_n=50)

# %%
npt.bar_ngram(title='bi-gram', ngram=3, top_n=20)

# %%
npt.bar_ngram(title='bi-gram', ngram=3, top_n=20, stopwords=stopwords)

# %%
# 2. N-gram tree Map
npt.treemap(title='Tree of Most Common Words', ngram=2, top_n=20, stopwords=stopwords)

# %%
# 3. Histogram of the word count
npt.word_distribution(title='words distribution')

# %%
# 4. wordcloud
npt.wordcloud(stopwords=stopwords, colormap='tab20_r')

# %%
# 5. co-occurrence networks
npt.build_graph(stopwords=stopwords, min_edge_frequency=3)

npt.co_network(title='Co-occurrence network')
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-76-8032c21038d7> in <module>
#       1 # 5. co-occurrence networks
# ----> 2 npt.build_graph(stopwords=stopwords, min_edge_frequency=3)
#       3
#       4 npt.co_network(title='Co-occurrence network')
#
# ~/AI-system/visualizer/nlplot/nlplot.py in build_graph(self, stopwords, min_edge_frequency)
#     505         # create community
#     506         # https://networkx.github.io/documentation/stable/reference/algorithms/community.html#module-networkx.algorithms.community.modularity_max
# --> 507         self.communities = community.greedy_modularity_communities(self.G)
#     508         self.communities_dict = {}
#     509         nodes_in_community = [list(i) for i in self.communities]
#
# ~/environments/experiment_env/lib/python3.6/site-packages/networkx/algorithms/community/modularity_max.py in greedy_modularity_communities(G, weight)
#      53     N = len(G.nodes())
#      54     m = sum([d.get("weight", 1) for u, v, d in G.edges(data=True)])
# ---> 55     q0 = 1.0 / (2.0 * m)
#      56
#      57     # Map node labels to contiguous integers
#
# ZeroDivisionError: float division by zero

# %%
# The number of nodes and edges to which this output is plotted.
# If this number is too large, plotting will take a long time, so adjust the [min_edge_frequency] well.
#>> node_size:70, edge_size:166


# 7. pyLDAvis
# If you want to run it in a notebook environment, you need to use the import and magic commands
import pyLDAvis
pyLDAvis.enable_notebook()
npt.ldavis(num_topics=5, passes=5, save=False)
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 3      0.125021 -0.021111       1        1  27.236662
# 4      0.112320  0.115090       2        1  20.202738
# 2     -0.006493 -0.126760       3        1  19.232437
# 0     -0.033530 -0.028345       4        1  18.740173
# 1     -0.197318  0.061125       5        1  14.587994, topic_info=       Term        Freq       Total Category  logprob  loglift
# 173   コンテンツ   14.000000   14.000000  Default  30.0000  30.0000
# 35       端末  104.000000  104.000000  Default  29.0000  29.0000
# 52      アプリ   29.000000   29.000000  Default  28.0000  28.0000
# 83       登録   36.000000   36.000000  Default  27.0000  27.0000
# 64       配布    8.000000    8.000000  Default  26.0000  26.0000
# ..      ...         ...         ...      ...      ...      ...
# 69       PC    1.983391    7.288870   Topic5  -4.5966   0.6234
# 175     データ    1.882687    6.503334   Topic5  -4.6487   0.6854
# 57       使う    1.782331    7.314974   Topic5  -4.7035   0.5130
# 27      サーバ    1.830104   17.227402   Topic5  -4.6770  -0.3172
# 107  インストール    1.753463   11.435184   Topic5  -4.7198   0.0499
#
# [282 rows x 6 columns], token_table=      Topic      Freq     Term
# term
# 10        2  0.878675       AD
# 10        4  0.109834       AD
# 11        2  0.725842   Active
# 213       3  0.810772      Add
# 38        1  0.191485  Android
# ...     ...       ...      ...
# 112       1  0.811683       除く
# 80        1  0.811683       階層
# 99        1  0.811685       項目
# 9         1  0.522481       順序
# 9         4  0.522481       順序
#
# [311 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[4, 5, 3, 1, 2])

# %%
# 6. sunburst chart
npt.sunburst(title='sunburst chart', colorscale=True)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-63-5b4aff576f95> in <module>
#       1 # 6. sunburst chart
# ----> 2 npt.sunburst(title='sunburst chart', colorscale=True)
#
# ~/AI-system/visualizer/nlplot/nlplot.py in sunburst(self, title, colorscale, color_col, color_continuous_scale, width, height, save)
#     690                               color_continuous_scale=color_continuous_scale,
#     691                               color_continuous_midpoint=np.average(_df[color_col],
# --> 692                               weights=_df[color_col]))
#     693
#     694         fig.update_layout(
#
# <__array_function__ internals> in average(*args, **kwargs)
#
# ~/amiebot/experiment_env/lib/python3.6/site-packages/numpy/lib/function_base.py in average(a, axis, weights, returned)
#     408         if np.any(scl == 0.0):
#     409             raise ZeroDivisionError(
# --> 410                 "Weights sum to zero, can't be normalized")
#     411
#     412         avg = np.multiply(a, wgt, dtype=result_dtype).sum(axis)/scl
#
# ZeroDivisionError: Weights sum to zero, can't be normalized
